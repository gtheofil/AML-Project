# %%
import os
import serial
import csv
import re
import time
import cv2
import random
import pandas as pd
import numpy as np
from datetime import datetime
from multiprocessing import Process, Event, Manager, freeze_support
import threading

def record_sensor_data(data_buffer, stop_event, recording_enabled, filename, serial_port, baud_rate):
    """ Collect EMG and IMU data when recording is enabled. """
    ser = serial.Serial(serial_port, baud_rate, timeout=1)
    print(f"[INFO] Data will be saved in: {filename}")
    
    with open(filename, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["Time (ms)", "EMG1", "EMG2", "EMG3", "EMG4", "AccX", "AccY", "AccZ", "GyroX", "GyroY", "GyroZ"])

        start_time = datetime.now()
        try:
            while not stop_event.is_set():
                line = ser.readline().decode('utf-8', errors='ignore').strip()
                if line:
                    parts = line.split()
                    if len(parts) == 10:
                        try:
                            emg_values = list(map(int, parts[:4]))  # EMG data
                            imu_values = list(map(int, parts[4:]))  # IMU data
                            elapsed_time = (datetime.now() - start_time).total_seconds() * 1000  # ms

                            if recording_enabled.is_set():
                                data_buffer.append([elapsed_time] + emg_values + imu_values)

                        except ValueError:
                            print(f"[WARNING] Invalid data: {line}")

            print("[INFO] Data collection finished")

        except KeyboardInterrupt:
            print("\n[INFO] Data collection manually stopped")

        finally:
            ser.close()
            print("[INFO] Serial port closed")

def run_visual_guidance(data_buffer, stop_event, recording_enabled, filename, root):
    """ Run the visual guidance, controlling when sensor data is collected, and repeat it 25 times. """
    image_folder = r"alpha"
    excel_file = r"shuffle_order.xlsx"

    # ✅ 检查 A.png 是否存在
    image_file = "A.png"
    img_path = os.path.join(image_folder, image_file)
    if not os.path.exists(img_path):
        print(f"❌ 文件 {img_path} 不存在，请检查！")
        exit()

    # ✅ 读取或创建 Excel 文件
    if os.path.exists(excel_file):
        df = pd.read_excel(excel_file, engine='openpyxl')
    else:
        df = pd.DataFrame()

    # ✅ 记录 A 的标签到 Excel
    label_dict = {chr(i + 65): i + 1 for i in range(26)}
    label = label_dict.get("A", "UNKNOWN")
    new_row = pd.DataFrame([[label]])
    df = pd.concat([df, new_row], ignore_index=True)
    df.to_excel(excel_file, index=False, engine='openpyxl')

    # ✅ 读取 A.png 并处理透明背景
    img = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)
    if img is None or img.size == 0:
        print(f"❌ 无法打开图片: {image_file}")
        exit()

    if img.shape[-1] == 4:
        bgr = img[:, :, :3]
        alpha = img[:, :, 3]  
        white_bg = np.ones_like(bgr, dtype=np.uint8) * 255
        alpha = alpha[:, :, np.newaxis] / 255.0
        img = (bgr * alpha + white_bg * (1 - alpha)).astype(np.uint8)

    # ✅ **重复执行 25 次**
    for trial in range(1, 26):
        if stop_event.is_set():
            break  # 终止所有循环

        # **🔴 PREPARE STAGE (2 秒)**
        recording_enabled.clear()
        print(f"[INFO] Trial {trial}: Prepare stage for {image_file}")

        start_time = time.time()
        for countdown in range(2, 0, -1):
            if stop_event.is_set():
                return
            img_copy = img.copy()
            cv2.putText(img_copy, f"Trial {trial}: Prepare {countdown}", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
            cv2.imshow("Visual Guidance", img_copy)
            elapsed = time.time() - start_time
            cv2.waitKey(max(1, int((2 - elapsed) * 1000 / countdown)))  
        cv2.waitKey(1)

        # **🟢 GO STAGE (5 秒, 开始记录)**
        print(f"[INFO] Trial {trial}: GO stage started for {image_file}")
        recording_enabled.set()

        start_time = time.time()
        for countdown in range(5, 0, -1):
            if stop_event.is_set():
                return
            img_copy = img.copy()
            cv2.putText(img_copy, f"Trial {trial}: GO {countdown}", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.imshow("Visual Guidance", img_copy)
            elapsed = time.time() - start_time
            cv2.waitKey(max(1, int((5 - elapsed) * 1000 / countdown)))  
        cv2.waitKey(1)

        # **📄 结束后写入 CSV 文件**
        recording_enabled.clear()
        print(f"[INFO] Trial {trial}: GO stage complete, saving data...")

        if data_buffer:  # 确保有数据
            with open(filename, 'a', newline='') as csvfile:
                writer = csv.writer(csvfile)
                writer.writerows(list(data_buffer))
            data_buffer[:] = []  # 清空缓冲区

        time.sleep(2)  # 额外的休息时间，确保节奏稳定

    print("[INFO] All 25 trials completed!")
    cv2.destroyAllWindows()
    stop_event.set()  # **停止进程**


if __name__ == '__main__':
    import serial.tools.list_ports
    print([port.device for port in serial.tools.list_ports.comports()])

    freeze_support()  # Windows 多进程支持

    manager = Manager()
    data_buffer = manager.list()
    stop_event = Event()
    recording_enabled = Event()
    
    SERIAL_PORT = 'COM4'  # 确保端口正确
    BAUD_RATE = 115200

    data_dir = r"data\"
    os.makedirs(data_dir, exist_ok=True)

    existing_files = [f for f in os.listdir(data_dir) if f.startswith("sensor_data") and f.endswith(".csv")]
    file_numbers = [int(re.search(r"sensor_data(\d+)\.csv", f).group(1)) for f in existing_files if re.search(r"sensor_data(\d+)\.csv", f)]
    next_file_number = max(file_numbers, default=0) + 1

    filename = os.path.join(data_dir, f"sensor_data{next_file_number}.csv")

    process1 = Process(
        target=record_sensor_data, 
        args=(data_buffer, stop_event, recording_enabled, filename, SERIAL_PORT, BAUD_RATE)  
    )
    process1.start()

    run_visual_guidance(data_buffer, stop_event, recording_enabled, filename, data_dir)

    stop_event.set()
    process1.terminate()
    process1.join()

    print("[INFO] All processes have safely exited")
# Out:
# []
# [INFO] Trial 1: Prepare stage for A.png
# [INFO] Trial 1: GO stage started for A.png
# [INFO] Trial 1: GO stage complete, saving data...
# [INFO] Trial 2: Prepare stage for A.png
# [INFO] Trial 2: GO stage started for A.png
# [INFO] Trial 2: GO stage complete, saving data...
# [INFO] Trial 3: Prepare stage for A.png
# [INFO] Trial 3: GO stage started for A.png
# [INFO] Trial 3: GO stage complete, saving data...
# [INFO] Trial 4: Prepare stage for A.png
# [INFO] Trial 4: GO stage started for A.png
# [INFO] Trial 4: GO stage complete, saving data...
# [INFO] Trial 5: Prepare stage for A.png
# [INFO] Trial 5: GO stage started for A.png
# [INFO] Trial 5: GO stage complete, saving data...
# [INFO] Trial 6: Prepare stage for A.png
# [INFO] Trial 6: GO stage started for A.png
# [INFO] Trial 6: GO stage complete, saving data...
# [INFO] Trial 7: Prepare stage for A.png
# [INFO] Trial 7: GO stage started for A.png
# [INFO] Trial 7: GO stage complete, saving data...
# [INFO] Trial 8: Prepare stage for A.png
# [INFO] Trial 8: GO stage started for A.png
# [INFO] Trial 8: GO stage complete, saving data...
# [INFO] Trial 9: Prepare stage for A.png
# [INFO] Trial 9: GO stage started for A.png
# [INFO] Trial 9: GO stage complete, saving data...
# [INFO] Trial 10: Prepare stage for A.png
# [INFO] Trial 10: GO stage started for A.png
# [INFO] Trial 10: GO stage complete, saving data...
# [INFO] Trial 11: Prepare stage for A.png
# [INFO] Trial 11: GO stage started for A.png
# [INFO] Trial 11: GO stage complete, saving data...
# [INFO] Trial 12: Prepare stage for A.png
# [INFO] Trial 12: GO stage started for A.png
# [INFO] Trial 12: GO stage complete, saving data...
# [INFO] Trial 13: Prepare stage for A.png
# [INFO] Trial 13: GO stage started for A.png
# [INFO] Trial 13: GO stage complete, saving data...
# [INFO] Trial 14: Prepare stage for A.png
# [INFO] Trial 14: GO stage started for A.png
# [INFO] Trial 14: GO stage complete, saving data...
# [INFO] Trial 15: Prepare stage for A.png
# [INFO] Trial 15: GO stage started for A.png
# [INFO] Trial 15: GO stage complete, saving data...
# [INFO] Trial 16: Prepare stage for A.png
# [INFO] Trial 16: GO stage started for A.png
# [INFO] Trial 16: GO stage complete, saving data...
# [INFO] Trial 17: Prepare stage for A.png
# [INFO] Trial 17: GO stage started for A.png
# [INFO] Trial 17: GO stage complete, saving data...
# [INFO] Trial 18: Prepare stage for A.png
# [INFO] Trial 18: GO stage started for A.png
# [INFO] Trial 18: GO stage complete, saving data...
# [INFO] Trial 19: Prepare stage for A.png
# [INFO] Trial 19: GO stage started for A.png
# [INFO] Trial 19: GO stage complete, saving data...
# [INFO] Trial 20: Prepare stage for A.png
# [INFO] Trial 20: GO stage started for A.png
# [INFO] Trial 20: GO stage complete, saving data...
# [INFO] Trial 21: Prepare stage for A.png
# [INFO] Trial 21: GO stage started for A.png
# [INFO] Trial 21: GO stage complete, saving data...
# [INFO] Trial 22: Prepare stage for A.png
# [INFO] Trial 22: GO stage started for A.png
# [INFO] Trial 22: GO stage complete, saving data...
# [INFO] Trial 23: Prepare stage for A.png
# [INFO] Trial 23: GO stage started for A.png
# [INFO] Trial 23: GO stage complete, saving data...
# [INFO] Trial 24: Prepare stage for A.png
# [INFO] Trial 24: GO stage started for A.png
# [INFO] Trial 24: GO stage complete, saving data...
# [INFO] Trial 25: Prepare stage for A.png
# [INFO] Trial 25: GO stage started for A.png
# [INFO] Trial 25: GO stage complete, saving data...
# [INFO] All 25 trials completed!
# [INFO] All processes have safely exited
